# %% [markdown]
# # Retrieve Weather Data

# %%
# %config Completer.use_jedi = False

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json

from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %% [markdown]
# ## Create a new set of 2,000 random latitudes and longitudes

# %%
set_size = 2000

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=set_size)
lngs = np.random.uniform(low=-180.000, high=180.000, size=set_size)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %% [markdown]
# # Get the nearest city using the citipy module

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %% [markdown]
# # Perform an API call with the OpenWeatherMap

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# city_url = url + "&q=Boston"
# city_weather = requests.get(city_url).json()
# city_weather

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({
            "City": city.title(),
            "Country": city_country,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description": city_weather_desc
            # "Date": city_date,
            
        })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        # Important:
        # Generally, it isn't good coding practice to add the pass statement to the except block.
        # Ideally, we want to handle or catch each error as it happens and do something specific (e.g., add another try block or print out the error).

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | spanaway
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | prince albert
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | rocha
# Processing Record 10 of Set 1 | korla
# Processing Record 11 of Set 1 | kem
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | santa rita
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | nemuro
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | bonavista
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | pullman
# Processing Record 27 of Set 1 | pierre
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | rivadavia
# Processing Record 30 of Set 1 | santa marinella
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | poya
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | wanning
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | grindavik
# Processing Record 39 of Set 1 | miyazu
# Processing Record 40 of Set 1 | wamba
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 1 | soacha
# Processing Record 44 of Set 1 | baruun-urt
# Processing Record 45 of Set 1 | codrington
# Processing Record 46 of Set 1 | gorontalo
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | lwowek slaski
# Processing Record 49 of Set 1 | waipawa
# Processing Record 50 of Set 1 | svetlyy
# Processing Record 1 of Set 2 | tual
# Processing Record 2 of Set 2 | naushki
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | havelock
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | richards bay
# Processing Record 12 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 2 | bintulu
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | soure
# Processing Record 18 of Set 2 | penzance
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | zalantun
# Processing Record 26 of Set 2 | beringovskiy
# Processing Record 27 of Set 2 | vostok
# Processing Record 28 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 2 | palmer
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | aguimes
# Processing Record 36 of Set 2 | gat
# Processing Record 37 of Set 2 | miraflores
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | san jeronimo
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | kysyl-syr
# Processing Record 42 of Set 2 | los llanos de aridane
# Processing Record 43 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | kahului
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | gorom-gorom
# Processing Record 48 of Set 2 | sorland
# Processing Record 49 of Set 2 | lompoc
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | taltal
# Processing Record 2 of Set 3 | assiniboia
# Processing Record 3 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 3 | toora-khem
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | bubaque
# Processing Record 8 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | carros
# Processing Record 13 of Set 3 | arlit
# Processing Record 14 of Set 3 | nuoro
# Processing Record 15 of Set 3 | henties bay
# Processing Record 16 of Set 3 | kieta
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | sobolevo
# Processing Record 19 of Set 3 | beira
# Processing Record 20 of Set 3 | iztapa
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | buraydah
# Processing Record 24 of Set 3 | gisborne
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | braniewo
# Processing Record 28 of Set 3 | faya
# Processing Record 29 of Set 3 | general delgado
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | hamilton
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | broome
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | ishigaki
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | pangody
# Processing Record 42 of Set 3 | kutum
# Processing Record 43 of Set 3 | toktogul
# Processing Record 44 of Set 3 | fortuna
# Processing Record 45 of Set 3 | jalu
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | rio verde de mato grosso
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | sao jose da coroa grande
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | erenhot
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | salamiyah
# Processing Record 9 of Set 4 | gaya
# Processing Record 10 of Set 4 | grakhovo
# Processing Record 11 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 4 | saint-augustin
# Processing Record 13 of Set 4 | port macquarie
# Processing Record 14 of Set 4 | gladstone
# Processing Record 15 of Set 4 | ampanihy
# Processing Record 16 of Set 4 | camacari
# Processing Record 17 of Set 4 | sambava
# Processing Record 18 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 4 | pastos bons
# Processing Record 20 of Set 4 | prince rupert
# Processing Record 21 of Set 4 | alta floresta
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | northam
# Processing Record 24 of Set 4 | bolotnoye
# Processing Record 25 of Set 4 | nuevo progreso
# Processing Record 26 of Set 4 | puerto ayora
# Processing Record 27 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 4 | bundaberg
# Processing Record 29 of Set 4 | touros
# Processing Record 30 of Set 4 | lisakovsk
# Processing Record 31 of Set 4 | banepa
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | udachnyy
# Processing Record 34 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 4 | port alfred
# Processing Record 36 of Set 4 | balkanabat
# Processing Record 37 of Set 4 | ganzhou
# Processing Record 38 of Set 4 | charters towers
# Processing Record 39 of Set 4 | sitka
# Processing Record 40 of Set 4 | lasa
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | husavik
# Processing Record 43 of Set 4 | norman wells
# Processing Record 44 of Set 4 | almaznyy
# Processing Record 45 of Set 4 | punata
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | hay river
# Processing Record 49 of Set 4 | zhuanghe
# Processing Record 50 of Set 4 | baherden
# Processing Record 1 of Set 5 | seoul
# Processing Record 2 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 5 | port augusta
# Processing Record 4 of Set 5 | andenes
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | kailua
# Processing Record 7 of Set 5 | bandarbeyla
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | nanortalik
# Processing Record 10 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 5 | khani
# Processing Record 12 of Set 5 | sihora
# Processing Record 13 of Set 5 | puerto asis
# Processing Record 14 of Set 5 | puksoozero
# Processing Record 15 of Set 5 | saint-joseph
# Processing Record 16 of Set 5 | talcahuano
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | rio gallegos
# Processing Record 19 of Set 5 | verkhnyaya inta
# Processing Record 20 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 5 | marawi
# Processing Record 22 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 5 | kagadi
# Processing Record 24 of Set 5 | fort-shevchenko
# Processing Record 25 of Set 5 | fare
# Processing Record 26 of Set 5 | caravelas
# Processing Record 27 of Set 5 | mar del plata
# Processing Record 28 of Set 5 | kangaatsiaq
# Processing Record 29 of Set 5 | georgetown
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | pareora
# Processing Record 32 of Set 5 | kingaroy
# Processing Record 33 of Set 5 | pokhara
# Processing Record 34 of Set 5 | sabla
# Processing Record 35 of Set 5 | westport
# Processing Record 36 of Set 5 | kajaani
# Processing Record 37 of Set 5 | maloh
# Processing Record 38 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 5 | lazaro cardenas
# Processing Record 40 of Set 5 | vestmannaeyjar
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | wajima
# Processing Record 43 of Set 5 | bana
# Processing Record 44 of Set 5 | boo
# Processing Record 45 of Set 5 | bam
# Processing Record 46 of Set 5 | glushkovo
# Processing Record 47 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | la ronge
# Processing Record 49 of Set 5 | merta
# Processing Record 50 of Set 5 | porto novo
# Processing Record 1 of Set 6 | la plata
# Processing Record 2 of Set 6 | tautira
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | erzin
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | lagoa
# Processing Record 7 of Set 6 | half moon bay
# Processing Record 8 of Set 6 | lata
# Processing Record 9 of Set 6 | moranbah
# Processing Record 10 of Set 6 | anadyr
# Processing Record 11 of Set 6 | aljojuca
# Processing Record 12 of Set 6 | jibuti
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | adrar
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | macia
# Processing Record 18 of Set 6 | monte alegre
# Processing Record 19 of Set 6 | xiuyan
# Processing Record 20 of Set 6 | pevek
# Processing Record 21 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 6 | acapulco
# Processing Record 23 of Set 6 | daru
# Processing Record 24 of Set 6 | nioro
# Processing Record 25 of Set 6 | price
# Processing Record 26 of Set 6 | myitkyina
# Processing Record 27 of Set 6 | henderson
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | sibolga
# Processing Record 30 of Set 6 | ambulu
# Processing Record 31 of Set 6 | carnarvon
# Processing Record 32 of Set 6 | san remigio
# Processing Record 33 of Set 6 | zeya
# Processing Record 34 of Set 6 | kungurtug
# Processing Record 35 of Set 6 | mega
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | qaqortoq
# Processing Record 38 of Set 6 | barcelos
# Processing Record 39 of Set 6 | kwinana
# Processing Record 40 of Set 6 | zinder
# Processing Record 41 of Set 6 | basco
# Processing Record 42 of Set 6 | sur
# Processing Record 43 of Set 6 | suchiapa
# Processing Record 44 of Set 6 | changping
# Processing Record 45 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 6 | hasaki
# Processing Record 47 of Set 6 | varna
# Processing Record 48 of Set 6 | vardo
# Processing Record 49 of Set 6 | eagle pass
# Processing Record 50 of Set 6 | matara
# Processing Record 1 of Set 7 | chapais
# Processing Record 2 of Set 7 | haimen
# Processing Record 3 of Set 7 | khatauli
# Processing Record 4 of Set 7 | sinfra
# Processing Record 5 of Set 7 | mogocha
# Processing Record 6 of Set 7 | snezhnogorsk
# Processing Record 7 of Set 7 | naze
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | eyrarbakki
# Processing Record 10 of Set 7 | menongue
# Processing Record 11 of Set 7 | oparino
# Processing Record 12 of Set 7 | chimoio
# Processing Record 13 of Set 7 | togur
# Processing Record 14 of Set 7 | ulladulla
# Processing Record 15 of Set 7 | flin flon
# Processing Record 16 of Set 7 | carballo
# Processing Record 17 of Set 7 | srandakan
# Processing Record 18 of Set 7 | goderich
# Processing Record 19 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 20 of Set 7 | suao
# City not found. Skipping...
# Processing Record 21 of Set 7 | lieksa
# Processing Record 22 of Set 7 | ponazyrevo
# Processing Record 23 of Set 7 | gimli
# Processing Record 24 of Set 7 | rio grande
# Processing Record 25 of Set 7 | tynda
# Processing Record 26 of Set 7 | polyanka
# Processing Record 27 of Set 7 | bosobolo
# Processing Record 28 of Set 7 | harlingen
# Processing Record 29 of Set 7 | toungoo
# City not found. Skipping...
# Processing Record 30 of Set 7 | san ramon
# Processing Record 31 of Set 7 | brasilia
# Processing Record 32 of Set 7 | velingara
# Processing Record 33 of Set 7 | edmundston
# Processing Record 34 of Set 7 | pa daet
# Processing Record 35 of Set 7 | andra
# Processing Record 36 of Set 7 | karasjok
# Processing Record 37 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 7 | kavieng
# Processing Record 39 of Set 7 | camaqua
# Processing Record 40 of Set 7 | baykit
# Processing Record 41 of Set 7 | sokoto
# Processing Record 42 of Set 7 | dingle
# Processing Record 43 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 7 | ust-nera
# Processing Record 45 of Set 7 | mount gambier
# Processing Record 46 of Set 7 | katobu
# Processing Record 47 of Set 7 | labuan
# Processing Record 48 of Set 7 | muskegon
# Processing Record 49 of Set 7 | alakurtti
# Processing Record 50 of Set 7 | viedma
# Processing Record 1 of Set 8 | coihueco
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 8 | tamiahua
# Processing Record 4 of Set 8 | seredka
# Processing Record 5 of Set 8 | bac lieu
# Processing Record 6 of Set 8 | ordzhonikidze
# Processing Record 7 of Set 8 | aregua
# Processing Record 8 of Set 8 | epe
# Processing Record 9 of Set 8 | ahipara
# Processing Record 10 of Set 8 | benguela
# Processing Record 11 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 13 of Set 8 | san cristobal
# Processing Record 14 of Set 8 | sri aman
# Processing Record 15 of Set 8 | lucapa
# Processing Record 16 of Set 8 | jawhar
# Processing Record 17 of Set 8 | scarborough
# Processing Record 18 of Set 8 | pleasanton
# Processing Record 19 of Set 8 | adre
# Processing Record 20 of Set 8 | cheremukhovo
# Processing Record 21 of Set 8 | brae
# Processing Record 22 of Set 8 | abong mbang
# Processing Record 23 of Set 8 | majdanpek
# Processing Record 24 of Set 8 | luanda
# Processing Record 25 of Set 8 | taksimo
# Processing Record 26 of Set 8 | nortelandia
# Processing Record 27 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 28 of Set 8 | biak
# Processing Record 29 of Set 8 | yandyki
# Processing Record 30 of Set 8 | liku
# Processing Record 31 of Set 8 | yar-sale
# Processing Record 32 of Set 8 | gidam
# Processing Record 33 of Set 8 | miguel hidalgo
# Processing Record 34 of Set 8 | agva
# City not found. Skipping...
# Processing Record 35 of Set 8 | grand gaube
# Processing Record 36 of Set 8 | san joaquin
# Processing Record 37 of Set 8 | lakki marwat
# Processing Record 38 of Set 8 | poum
# Processing Record 39 of Set 8 | lavrentiya
# Processing Record 40 of Set 8 | charqueadas
# Processing Record 41 of Set 8 | sayansk
# Processing Record 42 of Set 8 | sept-iles
# Processing Record 43 of Set 8 | avera
# Processing Record 44 of Set 8 | cuamba
# Processing Record 45 of Set 8 | porto santo
# Processing Record 46 of Set 8 | mackay
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 8 | russell
# Processing Record 50 of Set 8 | karachi
# Processing Record 1 of Set 9 | najran
# Processing Record 2 of Set 9 | synya
# Processing Record 3 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 4 of Set 9 | hami
# Processing Record 5 of Set 9 | eyl
# Processing Record 6 of Set 9 | rawson
# Processing Record 7 of Set 9 | kaeo
# Processing Record 8 of Set 9 | mao
# Processing Record 9 of Set 9 | leningradskiy
# Processing Record 10 of Set 9 | akita
# Processing Record 11 of Set 9 | tarko-sale
# Processing Record 12 of Set 9 | caborca
# Processing Record 13 of Set 9 | bichura
# Processing Record 14 of Set 9 | cabedelo
# Processing Record 15 of Set 9 | atkarsk
# Processing Record 16 of Set 9 | kuryk
# Processing Record 17 of Set 9 | wilkie
# Processing Record 18 of Set 9 | yumen
# Processing Record 19 of Set 9 | erdenet
# Processing Record 20 of Set 9 | chihuahua
# Processing Record 21 of Set 9 | trzebiatow
# Processing Record 22 of Set 9 | brownsville
# Processing Record 23 of Set 9 | uglegorsk
# Processing Record 24 of Set 9 | carupano
# Processing Record 25 of Set 9 | te anau
# Processing Record 26 of Set 9 | saint-pierre
# Processing Record 27 of Set 9 | alofi
# Processing Record 28 of Set 9 | sinnamary
# Processing Record 29 of Set 9 | nelson
# Processing Record 30 of Set 9 | luquillo
# Processing Record 31 of Set 9 | melilla
# Processing Record 32 of Set 9 | svetlaya
# Processing Record 33 of Set 9 | okitipupa
# Processing Record 34 of Set 9 | piraju
# Processing Record 35 of Set 9 | meulaboh
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | saint-imier
# Processing Record 38 of Set 9 | airai
# Processing Record 39 of Set 9 | rorvik
# Processing Record 40 of Set 9 | tommot
# Processing Record 41 of Set 9 | zyryanka
# Processing Record 42 of Set 9 | nelson bay
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | kargasok
# Processing Record 45 of Set 9 | jiayuguan
# Processing Record 46 of Set 9 | north bend
# Processing Record 47 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 9 | wapi pathum
# Processing Record 49 of Set 9 | venice
# Processing Record 50 of Set 9 | beloha
# Processing Record 1 of Set 10 | valdivia
# Processing Record 2 of Set 10 | payakumbuh
# Processing Record 3 of Set 10 | nome
# Processing Record 4 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 10 | chingirlau
# Processing Record 6 of Set 10 | yarada
# Processing Record 7 of Set 10 | mlonggo
# Processing Record 8 of Set 10 | mukhen
# Processing Record 9 of Set 10 | san policarpo
# Processing Record 10 of Set 10 | salalah
# Processing Record 11 of Set 10 | mandiana
# Processing Record 12 of Set 10 | oistins
# Processing Record 13 of Set 10 | oranjemund
# Processing Record 14 of Set 10 | abalak
# Processing Record 15 of Set 10 | horsham
# Processing Record 16 of Set 10 | teya
# Processing Record 17 of Set 10 | papasquiaro
# City not found. Skipping...
# Processing Record 18 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 10 | mamakan
# Processing Record 20 of Set 10 | ejea de los caballeros
# Processing Record 21 of Set 10 | trairi
# Processing Record 22 of Set 10 | kasongo-lunda
# Processing Record 23 of Set 10 | nishihara
# Processing Record 24 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 25 of Set 10 | karratha
# Processing Record 26 of Set 10 | egvekinot
# Processing Record 27 of Set 10 | shahrud
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 10 | belozerskoye
# Processing Record 31 of Set 10 | hofn
# Processing Record 32 of Set 10 | zhuhai
# Processing Record 33 of Set 10 | vanderhoof
# Processing Record 34 of Set 10 | terrace
# Processing Record 35 of Set 10 | placido de castro
# Processing Record 36 of Set 10 | aksu
# Processing Record 37 of Set 10 | thai binh
# Processing Record 38 of Set 10 | juli
# Processing Record 39 of Set 10 | bilma
# Processing Record 40 of Set 10 | tucuma
# Processing Record 41 of Set 10 | nizhniy baskunchak
# Processing Record 42 of Set 10 | zhezkazgan
# Processing Record 43 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 10 | aykhal
# Processing Record 45 of Set 10 | harper
# Processing Record 46 of Set 10 | chimore
# Processing Record 47 of Set 10 | wylie
# Processing Record 48 of Set 10 | san quintin
# Processing Record 49 of Set 10 | atar
# Processing Record 50 of Set 10 | narsaq
# Processing Record 1 of Set 11 | cairns
# Processing Record 2 of Set 11 | yakeshi
# Processing Record 3 of Set 11 | the valley
# Processing Record 4 of Set 11 | suntar
# Processing Record 5 of Set 11 | qinzhou
# Processing Record 6 of Set 11 | manica
# Processing Record 7 of Set 11 | sucre
# Processing Record 8 of Set 11 | katsuura
# Processing Record 9 of Set 11 | yulara
# Processing Record 10 of Set 11 | mosquera
# Processing Record 11 of Set 11 | kosonsoy
# Processing Record 12 of Set 11 | semirara
# Processing Record 13 of Set 11 | puerto padre
# Processing Record 14 of Set 11 | maceio
# Processing Record 15 of Set 11 | lumeje
# Processing Record 16 of Set 11 | pital
# Processing Record 17 of Set 11 | buenos aires
# Processing Record 18 of Set 11 | namatanai
# Processing Record 19 of Set 11 | banjar
# Processing Record 20 of Set 11 | bongandanga
# Processing Record 21 of Set 11 | llandrindod wells
# Processing Record 22 of Set 11 | aquiraz
# Processing Record 23 of Set 11 | soyo
# Processing Record 24 of Set 11 | flinders
# Processing Record 25 of Set 11 | kananga
# Processing Record 26 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 11 | khanpur
# Processing Record 30 of Set 11 | west wendover
# Processing Record 31 of Set 11 | salinas
# Processing Record 32 of Set 11 | praia da vitoria
# Processing Record 33 of Set 11 | gazanjyk
# Processing Record 34 of Set 11 | ixtapa
# Processing Record 35 of Set 11 | bumba
# Processing Record 36 of Set 11 | bushehr
# Processing Record 37 of Set 11 | kruisfontein
# Processing Record 38 of Set 11 | obo
# Processing Record 39 of Set 11 | ternate
# Processing Record 40 of Set 11 | axim
# Processing Record 41 of Set 11 | akureyri
# Processing Record 42 of Set 11 | tevriz
# Processing Record 43 of Set 11 | muscat
# Processing Record 44 of Set 11 | cayenne
# Processing Record 45 of Set 11 | port hedland
# Processing Record 46 of Set 11 | ugoofaaru
# Processing Record 47 of Set 11 | pasighat
# Processing Record 48 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 11 | krasnyy luch
# Processing Record 50 of Set 11 | burnie
# Processing Record 1 of Set 12 | jumla
# Processing Record 2 of Set 12 | camacha
# Processing Record 3 of Set 12 | wellington
# Processing Record 4 of Set 12 | kaoma
# Processing Record 5 of Set 12 | catamarca
# Processing Record 6 of Set 12 | komsomolskiy
# Processing Record 7 of Set 12 | boguchany
# Processing Record 8 of Set 12 | tilichiki
# Processing Record 9 of Set 12 | bambui
# Processing Record 10 of Set 12 | bannu
# Processing Record 11 of Set 12 | oktyabrskiy
# Processing Record 12 of Set 12 | spring valley
# Processing Record 13 of Set 12 | odesskoye
# Processing Record 14 of Set 12 | natchitoches
# Processing Record 15 of Set 12 | hyeres
# Processing Record 16 of Set 12 | varnamo
# Processing Record 17 of Set 12 | coquimbo
# Processing Record 18 of Set 12 | trincomalee
# Processing Record 19 of Set 12 | hobyo
# Processing Record 20 of Set 12 | bathsheba
# Processing Record 21 of Set 12 | port hardy
# Processing Record 22 of Set 12 | lindi
# Processing Record 23 of Set 12 | bereda
# Processing Record 24 of Set 12 | aklavik
# Processing Record 25 of Set 12 | pontal do parana
# Processing Record 26 of Set 12 | ararat
# Processing Record 27 of Set 12 | oltu
# Processing Record 28 of Set 12 | galesong
# Processing Record 29 of Set 12 | buchanan
# Processing Record 30 of Set 12 | waingapu
# Processing Record 31 of Set 12 | cherdyn
# Processing Record 32 of Set 12 | sungaipenuh
# Processing Record 33 of Set 12 | mayumba
# Processing Record 34 of Set 12 | kargil
# Processing Record 35 of Set 12 | ostashkov
# Processing Record 36 of Set 12 | peniche
# Processing Record 37 of Set 12 | linkoping
# Processing Record 38 of Set 12 | fohnsdorf
# Processing Record 39 of Set 12 | sakaiminato
# Processing Record 40 of Set 12 | college
# Processing Record 41 of Set 12 | abu samrah
# Processing Record 42 of Set 12 | bosansko grahovo
# Processing Record 43 of Set 12 | san luis
# Processing Record 44 of Set 12 | amga
# Processing Record 45 of Set 12 | filadelfia
# Processing Record 46 of Set 12 | tezu
# Processing Record 47 of Set 12 | pyinmana
# Processing Record 48 of Set 12 | vwawa
# Processing Record 49 of Set 12 | pemangkat
# Processing Record 50 of Set 12 | velikie luki
# City not found. Skipping...
# Processing Record 1 of Set 13 | vila franca do campo
# Processing Record 2 of Set 13 | zenzeli
# Processing Record 3 of Set 13 | curillo
# Processing Record 4 of Set 13 | kollam
# Processing Record 5 of Set 13 | east liverpool
# Processing Record 6 of Set 13 | banda aceh
# Processing Record 7 of Set 13 | prieska
# Processing Record 8 of Set 13 | ituango
# Processing Record 9 of Set 13 | bhadrachalam
# Processing Record 10 of Set 13 | caudry
# Processing Record 11 of Set 13 | paamiut
# Processing Record 12 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 13 | loandjili
# Processing Record 14 of Set 13 | ewa beach
# Processing Record 15 of Set 13 | kushima
# Processing Record 16 of Set 13 | sosnovo-ozerskoye
# Processing Record 17 of Set 13 | majene
# Processing Record 18 of Set 13 | khandyga
# Processing Record 19 of Set 13 | canchungo
# Processing Record 20 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 13 | katherine
# Processing Record 22 of Set 13 | bartica
# Processing Record 23 of Set 13 | klaksvik
# Processing Record 24 of Set 13 | torbat-e jam
# Processing Record 25 of Set 13 | ramsar
# Processing Record 26 of Set 13 | grajau
# Processing Record 27 of Set 13 | svarychiv
# Processing Record 28 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 13 | cravo norte
# Processing Record 30 of Set 13 | chara
# Processing Record 31 of Set 13 | susanino
# Processing Record 32 of Set 13 | alvorada
# Processing Record 33 of Set 13 | mildura
# Processing Record 34 of Set 13 | carutapera
# Processing Record 35 of Set 13 | baraboo
# Processing Record 36 of Set 13 | hovd
# Processing Record 37 of Set 13 | kanigoro
# Processing Record 38 of Set 13 | qostanay
# Processing Record 39 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 13 | tubuala
# Processing Record 41 of Set 13 | burica
# City not found. Skipping...
# Processing Record 42 of Set 13 | tapah
# Processing Record 43 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 44 of Set 13 | asilah
# Processing Record 45 of Set 13 | nurota
# Processing Record 46 of Set 13 | acarau
# Processing Record 47 of Set 13 | keti bandar
# Processing Record 48 of Set 13 | bjornevatn
# Processing Record 49 of Set 13 | moldava nad bodvou
# Processing Record 50 of Set 13 | nata
# Processing Record 1 of Set 14 | manggar
# Processing Record 2 of Set 14 | tadine
# Processing Record 3 of Set 14 | sindor
# Processing Record 4 of Set 14 | usinsk
# Processing Record 5 of Set 14 | lar
# Processing Record 6 of Set 14 | zabol
# Processing Record 7 of Set 14 | itarema
# Processing Record 8 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 14 | nizhniy kuranakh
# Processing Record 10 of Set 14 | cortez
# Processing Record 11 of Set 14 | camocim
# Processing Record 12 of Set 14 | laguna
# Processing Record 13 of Set 14 | tuy hoa
# Processing Record 14 of Set 14 | luau
# Processing Record 15 of Set 14 | engenheiro beltrao
# Processing Record 16 of Set 14 | asau
# Processing Record 17 of Set 14 | vryburg
# Processing Record 18 of Set 14 | cabo rojo
# Processing Record 19 of Set 14 | roma
# Processing Record 20 of Set 14 | haines junction
# Processing Record 21 of Set 14 | kargopol
# Processing Record 22 of Set 14 | birjand
# Processing Record 23 of Set 14 | margherita
# Processing Record 24 of Set 14 | ajdabiya
# Processing Record 25 of Set 14 | ponta delgada
# Processing Record 26 of Set 14 | liverpool
# Processing Record 27 of Set 14 | znamenskoye
# Processing Record 28 of Set 14 | wilmington island
# Processing Record 29 of Set 14 | buala
# Processing Record 30 of Set 14 | sechura
# Processing Record 31 of Set 14 | bilibino
# Processing Record 32 of Set 14 | necochea
# Processing Record 33 of Set 14 | betare oya
# Processing Record 34 of Set 14 | bage
# Processing Record 35 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 14 | elmadag
# Processing Record 37 of Set 14 | luena
# Processing Record 38 of Set 14 | hindang
# Processing Record 39 of Set 14 | abu kamal
# Processing Record 40 of Set 14 | bonoua
# Processing Record 41 of Set 14 | olafsvik
# Processing Record 42 of Set 14 | fez
# Processing Record 43 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 14 | tomatlan
# Processing Record 45 of Set 14 | kathmandu
# Processing Record 46 of Set 14 | shelton
# Processing Record 47 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 14 | baghdad
# Processing Record 49 of Set 14 | khor
# Processing Record 50 of Set 14 | ucluelet
# Processing Record 1 of Set 15 | horodnytsya
# Processing Record 2 of Set 15 | whitehorse
# Processing Record 3 of Set 15 | ochsenfurt
# Processing Record 4 of Set 15 | leninskoye
# Processing Record 5 of Set 15 | abha
# Processing Record 6 of Set 15 | bira
# Processing Record 7 of Set 15 | inuvik
# Processing Record 8 of Set 15 | vestmanna
# Processing Record 9 of Set 15 | casablanca
# Processing Record 10 of Set 15 | nizhneangarsk
# Processing Record 11 of Set 15 | eureka
# Processing Record 12 of Set 15 | padang
# Processing Record 13 of Set 15 | coahuayana
# Processing Record 14 of Set 15 | hambantota
# Processing Record 15 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 15 | guangyuan
# Processing Record 17 of Set 15 | apollonia
# Processing Record 18 of Set 15 | rach gia
# Processing Record 19 of Set 15 | sola
# Processing Record 20 of Set 15 | vao
# Processing Record 21 of Set 15 | maniitsoq
# Processing Record 22 of Set 15 | payo
# Processing Record 23 of Set 15 | sistranda
# Processing Record 24 of Set 15 | olavarria
# Processing Record 25 of Set 15 | hualmay
# Processing Record 26 of Set 15 | kununurra
# Processing Record 27 of Set 15 | nantucket
# Processing Record 28 of Set 15 | brindisi
# Processing Record 29 of Set 15 | auki
# Processing Record 30 of Set 15 | zhireken
# Processing Record 31 of Set 15 | maluay
# City not found. Skipping...
# Processing Record 32 of Set 15 | meadow lake
# Processing Record 33 of Set 15 | kinshasa
# Processing Record 34 of Set 15 | verkh-usugli
# Processing Record 35 of Set 15 | along
# Processing Record 36 of Set 15 | stutterheim
# Processing Record 37 of Set 15 | nouakchott
# Processing Record 38 of Set 15 | salta
# Processing Record 39 of Set 15 | mossendjo
# Processing Record 40 of Set 15 | zubtsov
# Processing Record 41 of Set 15 | itoman
# Processing Record 42 of Set 15 | okha
# Processing Record 43 of Set 15 | kapit
# Processing Record 44 of Set 15 | kalemie
# Processing Record 45 of Set 15 | jalostotitlan
# Processing Record 46 of Set 15 | isangel
# Processing Record 47 of Set 15 | liniere
# City not found. Skipping...
# Processing Record 48 of Set 15 | dalianwan
# Processing Record 49 of Set 15 | les cayes
# Processing Record 50 of Set 15 | huntsville
# Processing Record 1 of Set 16 | kuytun
# Processing Record 2 of Set 16 | vrangel
# Processing Record 3 of Set 16 | wum
# Processing Record 4 of Set 16 | bay city
# Processing Record 5 of Set 16 | jonkoping
# Processing Record 6 of Set 16 | jacareacanga
# Processing Record 7 of Set 16 | bridlington
# Processing Record 8 of Set 16 | srivardhan
# Processing Record 9 of Set 16 | fukue
# Processing Record 10 of Set 16 | cruz alta
# Processing Record 11 of Set 16 | ibanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Add the data to a new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Spanaway      US  47.1040 -122.4346     73.45        64          90
# 1          Vaini      TO -21.2000 -175.2000     73.56        94          90
# 2          Tiksi      RU  71.6872  128.8694     48.65        64          95
# 3    New Norfolk      AU -42.7826  147.0587     54.91        72         100
# 4       Cherskiy      RU  68.7500  161.3000     44.85        76         100
# 5      Cape Town      ZA -33.9258   18.4232     67.87        74         100
# 6  Prince Albert      CA  53.2001 -105.7677     51.75        82           1
# 7          Rocha      UY -34.4833  -54.3333     38.93        87           0
# 8          Korla      CN  41.7597   86.1469     85.35        32         100
# 9            Kem      RU  64.9555   34.5793     60.28        80          90
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1       10.36       moderate rain
# 2        3.27     overcast clouds
# 3        1.99          light rain
# 4       14.99     overcast clouds
# 5        1.99     overcast clouds
# 6        3.44           clear sky
# 7        4.65           clear sky
# 8       17.92     overcast clouds
# 9        7.40     overcast clouds

# %%
# Reorder
# new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
# city_data_df = city_data_df[new_column_order]
# city_data_df

# %% [markdown]
# # Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
